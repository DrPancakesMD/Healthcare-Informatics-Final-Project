# %%
import pandas as pd
import numpy as np

# %% [markdown]
# First Dataset

# %%
df1 = pd.read_csv("physician_compare/Physician_Compare_2016_Group_Public_Reporting.csv", 
                  dtype = ['object','object', 'object', 'object', 'object', 'object',
                          'object', 'object', 'object', 'object','float64', 'float64', 'float64', 
                           'float64', 'float64', 'float64', 'object', 'object'])
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ba9822d0f3f6> in <module>()
#       2                   dtype = ['object','object', 'object', 'object', 'object', 'object',
#       3                           'object', 'object', 'object', 'object','float64', 'float64', 'float64',
# ----> 4                            'float64', 'float64', 'float64', 'object', 'object'])
#       5 df1
#
# ...

# %%
df1["Measure Title"].unique()
# Out:
# array([nan, 'Preventive Care and Screening: Influenza Immunization',
#        'Pneumonia Vaccination Status for Older Adults',
#        'Colorectal Cancer Screening',
#        'Diabetes: Eye Exam - National Quality Strategy',
#        'Coronary Artery Disease (CAD): Angiotensin-Converting Enzyme (ACE) Inhibitor or Angiotensin Receptor Blocker (ARB) Therapy - Diabetes or Left Ventricular Systolic Dysfunction (LVEF < 40%)',
#        'Preventive Care and Screening: Body Mass Index (BMI) Screening and Follow-Up Plan',
#        'Documentation of Current Medications in the Medical Record',
#        'Preventive Care and Screening: Screening for Clinical Depression and Follow-Up Plan',
#        'Ischemic Vascular Disease (IVD): Use of Aspirin or Another Antithrombotic',
#        'Preventive Care and Screening: Screening for High Blood Pressure and Follow-Up Documented',
#        'Falls: Screening for Future Fall Risk',
# ...

# %% [markdown]
# Second Dataset

# %%
df2 = pd.read_csv("physician_compare/Physician_Compare_2016_Group_Public_Reporting-_Patient_Experience.csv")
df2
# Out:
#      Organization legal name or 'doing business as' name  Group PAC ID  State  \
# 0                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 1                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 2                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 3                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 4                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 5                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 6                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 7                     HERITAGE VALLEY MEDICAL GROUP INC       42105678     PA
# 8                    MAYO CLINIC HEALTH SYSTEM-OWATONNA       42111981     MN
# 9                    MAYO CLINIC HEALTH SYSTEM-OWATONNA       42111981     MN
# 10                   MAYO CLINIC HEALTH SYSTEM-OWATONNA       42111981     MN
# ...

# %%
np.unique(df2["Measure Title"])
# Out:
# array(['Attention to patient medication cost.',
#        'Between visit communication.',
#        'Clinicians working together for your care.',
#        'Courteous and helpful office staff.',
#        'Getting timely care, appointments, and information.',
#        'Health promotion and education.',
#        'How well clinicians communicate.',
#        "Patients' rating of clinicians."], dtype=object)

# %% [markdown]
# Third Dataset

# %%
df3 = pd.read_csv("physician_compare/Physician_Compare_2015_Individual_EP_Public_Reporting___Performance_Scores.csv")
df3
# Out:
#                NPI      PAC ID    Last Name First Name Measure Identifier  \
# 0       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_110_1
# 1       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_111_1
# 2       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_112_1
# 3       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_113_1
# 4       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_128_1
# 5       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_130_1
# 6       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_181_1
# 7       1508823618    42100117      GRIFFIN      DAVID      PQRS_EP_226_1
# 8       1508823618    42100117      GRIFFIN      DAVID       PQRS_EP_39_1
# 9       1477528776    42100133        SPEAR    JEFFREY      PQRS_EP_317_1
# 10      1477528776    42100133        SPEAR    JEFFREY       PQRS_EP_54_1
# 11      1154338044    42100190    VERBRUGGE       JOHN      PQRS_EP_317_1
# ...

# %%
np.unique(df3["Measure Title"])
# Out:
# array(['Achievement of Projected Effective Dose of Standardized Allergens for Patient Treated With Allergen Immunotherapy for at Least One Year',
#        'Acute Otitis Externa (AOE): Systemic Antimicrobial Therapy – Avoidance of Inappropriate Use',
#        'Acute Otitis Externa (AOE): Topical Therapy',
#        'Adequacy of bowel preparation',
#        'Adequate Compression at each visit for Patients with Venous Leg Ulcers (VLU)',
#        'Adequate Off-loading of Diabetic Foot Ulcers at each visit',
#        'Adherence to Antipsychotic Medications for Individuals with Schizophrenia',
#        'Adult Kidney Disease: Blood Pressure Management',
#        'Adult Kidney Disease: Laboratory Testing (Lipid Profile)',
#        'Adult Major Depressive Disorder (MDD): Coordination of Care of Patients with Specific Comorbid Conditions',
#        'Adult Sinusitis: Antibiotic Prescribed for Acute Sinusitis (Appropriate Use)*',
# ...

# %% [markdown]
# Fourth Dataset

# %%
df4 = pd.read_csv("physician_compare/Physician_Compare_National_Downloadable_File.csv")
df4
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15,25,26,28,29,30,31,32,33,34,36,40) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                 NPI      PAC ID Professional Enrollment ID         Last Name  \
# 0        1487927612  4880850486            I20120726000331              HALL
# 1        1235146762  2365435336            I20040406000367             WHITE
# 2        1285727842  5799762829            I20040707000479             CASHA
# 3        1295821098   840459889            I20120309000459            MORANZ
# 4        1063514289  1951391671            I20040514000778          MCGREGOR
# 5        1346282258  5395768527            I20060113000139          DAVIDSON
# 6        1932283124  5193762862            I20050415000143             CAGEN
# ...

# %%
np.unique(df4["Medical school name"])
# Out:
# array(['A T STILL UN, ARIZONA SCHL OF DENT.Y & ORAL HLTH',
#        'ADIO/PENNSYLVANIA INSTITUTE OF STRAIGHT CHIROPRACTIC',
#        'ALBANY MEDICAL COLLEGE OF UNION UNIVERSITY',
#        'ALBERT EINSTEIN COLLEGE OF MEDICINE OF YESHIVA UNIVERSITY',
#        'AMERICAN MEDICAL MISSIONARY COLLEGE',
#        'ARIZONA COLLEGE OF OSTEOPATHIC MEDICINE MID WESTERN UNIVERSITY',
#        'ATLANTA COLLEGE OF PHYSICIANS AND SURGEONS',
#        'ATLANTA SCHOOL OF MEDICINE', 'ATLANTIC MEDICAL COLLEGE',
#        'ATLANTIC STATES/COLUMBIA CHIROPRACTIC INSTITUTE',
#        'BALTIMORE MEDICAL COLLEGE',
#        'BALTIMORE UNIVERSITY SCHOOL OF MEDICINE',
#        'BARNES MEDICAL COLLEGE',
#        'BARRY UNIVERSITY SCHOOL PODIATRIC MEDICINE',
#        'BAYLOR COLLEGE OF DENTISTRY/TEXAS A AND M UNIVERSITY',
#        'BAYLOR COLLEGE OF MEDICINE',
#        'BEAUMONT HOSPITAL MEDIAL COLLEGE - NLG',
#        'BEBOUT COLLEGE OF CHIROPRACTIC',
# ...

# %%
df5 = pd.read_csv("medicares-doctor-comparison-scores/pl_pfile_20050523-20180909.csv")
df5
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                NPI  \
# 0       1124021324
# 1       1124021324
# 2       1063415271
# 3       1215930250
# 4       1326041468
# 5       1073516241
# 6       1699778720
# 7       1821091844
# 8       1821091844
# 9       1588667596
# 10      1689677809
# 11      1861495079
# 12      1215930425
# 13      1285637298
# 14      1285637298
# 15      1568465763
# 16      1013910124
# 17      1013910124
# 18      1013910124
# 19      1356344477
# 20      1871596999
# 21      1780687871
# 22      1932103264
# 23      1932103264
# 24      1932103264
# 25      1538162615
# 26      1154324234
# 27      1700889888
# 28      1902809080
# 29      1962405035
# ...            ...
# 129116  1043793862
# 129117  1386127132
# 129118  1356824106
# ...

# %%
df6 = pd.read_csv("medicares-doctor-comparison-scores/npidata_pfile_20050523-20180909.csv")
df6
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-0833b5d6691d> in <module>()
# ----> 1 df6 = pd.read_csv("medicares-doctor-comparison-scores/npidata_pfile_20050523-20180909.csv")
#       2 df6
#
# ...
