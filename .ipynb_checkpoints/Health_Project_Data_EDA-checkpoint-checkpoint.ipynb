# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Functin to Change Y and N to booleans

# %%
def convert_bool(col):
    if str(col).title() ==  "Y": #check for nan
        return True
    elif str(col).title() == "N":
        return False
    else:
        return col

# %% [markdown]
# ## Physician Care: Organization Performance

# %%
# Importing and changing categories
pc_org_perf = pd.read_csv("physician_compare/Physician_Compare_2016_Group_Public_Reporting.csv",
                  dtype = {"Organization legal name or 'doing business as' name" : "category",
                           "Group PAC ID" : "category",
                           "State" : "category",
                           "ACO PC ID 1" : "category",
                           "ACO Name 1" : "category",
                           "ACO PC ID 2" : "category",
                           "ACO Name 2" : "category",
                           "Measure Identifier" : "category",
                           "Measure Title" : "category",
                           "Measure Performance Rate": "float64",
                           "Denominator Count": "float64",
                           "Star Value": "float64",
                           "Five Star Benchmark": "float64",
                           "Footnote": "object",
                           "Collection Type": "object"},
                 converters={"Participating in PQRS": lambda x:convert_bool(x),
                             "Inverse Measure": lambda x:convert_bool(x),
                             "Reported on PC Live Site": lambda x:convert_bool(x)})

# Changing to boolean
pc_org_perf["Participating in PQRS"] = pc_org_perf["Participating in PQRS"].astype("bool")
pc_org_perf["Inverse Measure"] = pc_org_perf["Inverse Measure"].astype("bool")
pc_org_perf["Reported on PC Live Site"] = pc_org_perf["Reported on PC Live Site"].astype("bool")

# Display data frame
# pc_org_report

##Determining what datatypes are available 
#pc_org_perf.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_org_perf['Measure Title'].astype('str').unique()

# %%
pc_org_perf["Measure Title"].astype('str').unique()
# Out:
# array(['nan', 'Preventive Care and Screening: Influenza Immunization',
#        'Pneumonia Vaccination Status for Older Adults',
#        'Colorectal Cancer Screening',
#        'Diabetes: Eye Exam - National Quality Strategy',
#        'Coronary Artery Disease (CAD): Angiotensin-Converting Enzyme (ACE) Inhibitor or Angiotensin Receptor Blocker (ARB) Therapy - Diabetes or Left Ventricular Systolic Dysfunction (LVEF < 40%)',
#        'Preventive Care and Screening: Body Mass Index (BMI) Screening and Follow-Up Plan',
#        'Documentation of Current Medications in the Medical Record',
#        'Preventive Care and Screening: Screening for Clinical Depression and Follow-Up Plan',
#        'Ischemic Vascular Disease (IVD): Use of Aspirin or Another Antithrombotic',
#        'Preventive Care and Screening: Screening for High Blood Pressure and Follow-Up Documented',
#        'Falls: Screening for Future Fall Risk',
#        'Pain Assessment and Follow-Up', 'Functional Outcome Assessment',
#        'Preventive Care and Screening: Tobacco Use: Screening and Cessation Intervention',
#        'Prevention of Central Venous Catheter (CVC)-Related Bloodstream Infections',
#        'Perioperative Care: Selection of Prophylactic Antibiotic - First OR Second Generation Cephalosporin',
#        'Perioperative Care: Discontinuation of Prophylactic Parenteral Antibiotics (Non-Cardiac Procedures)',
#        'Perioperative Care: Venous Thromboembolism (VTE) Prophylaxis (When Indicated in ALL Patients)',
#        'Melanoma: Continuity of Care - Recall System',
#        'Melanoma: Overutilization of Imaging Studies in Melanoma',
#        'Biopsy Follow-Up',
#        'Tuberculosis Prevention for Psoriasis and Psoriatic Arthritis Patients on a Biological Immune Response Modifier',
#        'Radiology: Exposure Time Reported for Procedures Using Fluoroscopy',
#        'Use of High-Risk Medications in the Elderly',
#        'Urinary Incontinence: Assessment of Presence or Absence of Urinary Incontinence in Women Aged 65 Years and Older',
#        'Melanoma: Coordination of Care',
#        'Avoidance of Antibiotic Treatment in Adults With Acute Bronchitis',
#        'Medication Reconciliation Post-Discharge', 'Advance Care Plan',
#        'Emergency Medicine: 12-Lead Electrocardiogram (ECG) Performed for Non-Traumatic Chest Pain',
#        'Lung Cancer Reporting (Biopsy/Cytology Specimens)',
#        'Melanoma Reporting',
#        'Radiology: Inappropriate Use of "Probably Benign" Assessment Category in Mammography Screening',
#        'Nuclear Medicine: Correlation with Existing Imaging Studies for All Patients Undergoing Bone Scintigraphy',
#        'Radiology: Stenosis Measurement in Carotid Imaging Reports',
#        'Radiology: Reminder System for Screening Mammograms',
#        'Cardiac Stress Imaging Not Meeting Appropriate Use Criteria: Preoperative Evaluation in Low Risk Surgery Patients',
#        'Cardiac Stress Imaging Not Meeting Appropriate Use Criteria: Routine Testing After Percutaneous Coronary Intervention (PCI)',
#        'Cardiac Stress Imaging Not Meeting Appropriate Use Criteria: Testing in Asymptomatic, Low-Risk Patients',
#        'Falls: Risk Assessment', 'Falls: Plan of Care',
#        'Participation in a National Dose Index Registry',
#        'Breast Cancer: Hormonal Therapy for Stage IC - IIIC Estrogen Receptor/Progesterone Receptor (ER/PR) Positive Breast Cancer',
#        'Coronary Artery Disease (CAD): Antiplatelet Therapy',
#        'Elder Maltreatment Screen and Follow-Up Plan',
#        'Adult Kidney Disease: Laboratory Testing (Lipid Profile)',
#        'Osteoarthritis (OA): Function and Pain Assessment',
#        'Screening or Therapy for Osteoporosis for Women Aged 65 Years and Older',
#        'Acute Otitis Externa (AOE): Systemic Antimicrobial Therapy - Avoidance of Inappropriate Use',
#        'Coronary Artery Bypass Graft (CABG): Preoperative Beta-Blocker in Patients with Isolated CABG Surgery',
#        'Atrial Fibrillation and Atrial Flutter: Chronic Anticoagulation Therapy',
#        'Patient-Centered Surgical Risk Assessment and Communication',
#        'Adult Sinusitis: Antibiotic Prescribed for Acute Sinusitis (Appropriate Use)',
#        'Adult Sinusitis: Appropriate Choice of Antibiotic: Amoxicillin Prescribed for Patients with Acute Bacterial Sinusitis',
#        'Hepatitis C: One-Time Screening for Hepatitis C Virus (HCV) for Patients at Risk',
#        'Asthma: Pharmacologic Therapy for Persistent Asthma - Ambulatory Care Setting',
#        'Chronic Obstructive Pulmonary Disease (COPD): Spirometry Evaluation'],
#       dtype=object)

# %% [markdown]
# ## Physician Compare: Patient's Organization Experience

# %%
# Importing and changing categories
pc_org_pt_exp = pd.read_csv("physician_compare/Physician_Compare_2016_Group_Public_Reporting-_Patient_Experience.csv",
                  dtype = {"Organization legal name or 'doing business as' name" : "category",
                           "Group PAC ID" : "category",
                           "State" : "category",
                           "Measure Identifier" : "category",
                           "Measure Title" : "category",
                           "Measure Performance Rate": "float64",
                           "Denominator Count": "float64",
                           "Footnote": "object"})

# Display data frame
# pc_org_pt_exp

##Determining what datatypes are available 
#pc_org_report.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_org_pt_exp['Measure Title'].astype('str').unique()

# %%
pc_org_pt_exp['Measure Title'].astype('str').unique()
# Out:
# array(['Getting timely care, appointments, and information.',
#        'Between visit communication.',
#        'Attention to patient medicine cost.',
#        'How well clinicians communicate.',
#        "Patients' rating of clinicians.",
#        'Health promotion and education.',
#        'Courteous and helpful office staff.',
#        'Clinicians working together for your care.'], dtype=object)

# %% [markdown]
# ##  Physician Compare: Physician Performance

# %%
# Importing and changing categories
pc_phys_perf = pd.read_csv("physician_compare/Physician_Compare_2016_Individual_EP_Public_Reporting.csv",
                  dtype = {"NPI" : "category",
                           "PAC ID" : "category",
                           "Last Name" : "object",
                           "First Name" : "object",
                           "Measure Identifier" : "category",
                           "Measure Title" : "category",
                           "Measure Performance Rate": "float64",
                           "Reporting Mechanism": "category",
                           "Footnote": "object"},
                           converters={"Inverse Measure": lambda x:convert_bool(x),
                                      "Reported on PC Live Site": lambda x:convert_bool(x)})

# Converting to boolean
pc_phys_perf["Inverse Measure"] = pc_phys_perf["Inverse Measure"].astype("bool")
pc_phys_perf["Reported on PC Live Site"] = pc_phys_perf["Reported on PC Live Site"].astype("bool")

# Display data frame
# pc_phys_perf

##Determining what datatypes are available 
#pc_phys_perf.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_phys_perf['Measure Title'].astype('str').unique()

# %%
pc_phys_perf['Measure Title'].astype('str').unique()
# Out:
# array(['Preventive Care and Screening: Influenza Immunization',
#        'Pneumonia Vaccination Status for Older Adults',
#        'Colorectal Cancer Screening',
#        'Documentation of Current Medications in the Medical Record',
#        'Preventive Care and Screening: Tobacco Use: Screening and Cessation Intervention',
#        'Screening or Therapy for Osteoporosis for Women Aged 65 Years and Older',
#        'Urinary Incontinence: Assessment of Presence or Absence of Urinary Incontinence in Women Aged 65 Years and Older',
#        'Advance Care Plan', 'Pain Assessment and Follow-Up',
#        'Functional Outcome Assessment',
#        'Perioperative Care: Venous Thromboembolism (VTE) Prophylaxis (When Indicated in ALL Patients)',
#        'Nuclear Medicine: Correlation with Existing Imaging Studies for All Patients Undergoing Bone Scintigraphy',
#        'Melanoma: Continuity of Care - Recall System',
#        'Melanoma: Overutilization of Imaging Studies in Melanoma',
#        'Use of High-Risk Medications in the Elderly', 'Biopsy Follow-Up',
#        'Radiology: Stenosis Measurement in Carotid Imaging Reports',
#        'Perioperative Care: Selection of Prophylactic Antibiotic - First OR Second Generation Cephalosporin',
#        'Perioperative Care: Discontinuation of Prophylactic Parenteral Antibiotics (Non-Cardiac Procedures)',
#        'Patient-Centered Surgical Risk Assessment and Communication',
#        'Appropriate management of anticoagulation in the peri-procedural period rate - EGD',
#        'Adequacy of bowel preparation',
#        'Documentation of history and physical rate - Colonoscopy',
#        'Radiology: Exposure Time Reported for Procedures Using Fluoroscopy',
#        'Chronic Obstructive Pulmonary Disease (COPD): Spirometry Evaluation',
#        'Radiology: Reminder System for Screening Mammograms',
#        'Medication Reconciliation Post-Discharge',
#        'Prevention of Central Venous Catheter (CVC)-Related Bloodstream Infections',
#        'Falls: Risk Assessment', 'Falls: Plan of Care',
#        'Radiology: Inappropriate Use of "Probably Benign" Assessment Category in Mammography Screening',
#        'Glucocorticosteroids and Other Secondary Causes',
#        'Appropriate indication for colonoscopy',
#        'Melanoma: Coordination of Care',
#        'Tuberculosis Prevention for Psoriasis and Psoriatic Arthritis Patients on a Biological Immune Response Modifier',
#        'Osteoporosis: Pharmacologic Therapy for Men and Women Aged 50 Years and Older',
#        'Melanoma Reporting',
#        'Osteoarthritis (OA): Function and Pain Assessment',
#        'Colonoscopy Interval for Patients with a History of Adenomatous Polyps - Avoidance of Inappropriate Use',
#        'Orthopedic Pain: Mental Health Assessment',
#        'Cardiac Stress Imaging Not Meeting Appropriate Use Criteria: Routine Testing After Percutaneous Coronary Intervention (PCI)',
#        'Cardiac Stress Imaging Not Meeting Appropriate Use Criteria: Testing in Asymptomatic, Low-Risk Patients',
#        'Adult Sinusitis: Antibiotic Prescribed for Acute Sinusitis (Appropriate Use)',
#        'Functional Status Assessment for Patients with Rheumatoid Arthritis (RA)',
#        'Surgeon assessment for hereditary cause of breast cancer',
#        'Elder Maltreatment Screen and Follow-Up Plan',
#        'Use of Checklist or Protocol for Transfer of Care in Phase I recovery From Anesthesia Provider to PACU or ICU',
#        'Tobacco Use and Help with Quitting Among Adolescents',
#        'Acute Otitis Externa (AOE): Systemic Antimicrobial Therapy - Avoidance of Inappropriate Use',
#        'Adult Sinusitis: Appropriate Choice of Antibiotic: Amoxicillin Prescribed for Patients with Acute Bacterial Sinusitis',
#        'Disease Activity Measurement for Patients with Rheumatoid Arthritis (RA)',
#        'Endoscopy/Polyp Surveillance: Appropriate Follow-Up Interval for Normal Colonoscopy in Average Risk Patients',
#        'Chronic Obstructive Pulmonary Disease (COPD): Inhaled Bronchodilator Therapy',
#        'Atrial Fibrillation and Atrial Flutter: Chronic Anticoagulation Therapy',
#        'Avoiding intraoperative hypotension',
#        'Participation in a National Dose Index Registry',
#        'Hepatitis C: One-Time Screening for Hepatitis C Virus (HCV) for Patients at Risk',
#        'Rheumatoid Arthritis (RA): Functional Status Assessment',
#        "Barrett's Esophagus",
#        'Referral for Otologic Evaluation for Patients with Acute or Chronic Dizziness',
#        'Acute Otitis Externa (AOE): Topical Therapy',
#        'Cardiac Stress Imaging Not Meeting Appropriate Use Criteria: Preoperative Evaluation in Low Risk Surgery Patients',
#        'Lung Cancer Reporting (Biopsy/Cytology Specimens)',
#        'Core temperature measurement for all general anesthetics',
#        'Osteoporosis Screening for Women', 'Cervical Cancer Screening',
#        'Breast Cancer Screening', 'Colorectal Cancer screening',
#        'Pneumococcal Vaccination in Elderly', 'Depression Screening',
#        'Alcohol Misuse Screening',
#        'Tobacco Use: Screening and Cessation Intervention',
#        'Avoidance of Antibiotic Treatment in Adults With Acute Bronchitis',
#        'MBSC Venous Thromboembolism prophylaxis adherence rates for Perioperative Care',
#        'MBSC Venous Thromboembolism prophylaxis adherence rates for Postoperative Care',
#        'Hematology: Myelodysplastic Syndrome (MDS) and Acute Leukemias: Baseline Cytogenetic Testing Performed on Bone Marrow',
#        'Breast Cancer: Hormonal Therapy for Stage IC - IIIC Estrogen Receptor/Progesterone Receptor (ER/PR) Positive Breast Cancer',
#        'Asthma: Pharmacologic Therapy for Persistent Asthma - Ambulatory Care Setting',
#        'Zoster (Shingles) Vaccination',
#        'CG-CAHPS Adult Visit Composite Tracking',
#        'Orthopedic 3-Month Surgery Follow-up', 'CG-CAHPS Patient Rating',
#        'Blood glucose check prior to hyperbaric oxygen therapy (HBOT) treatment',
#        'Orthopedic Pain: Patient Reassessment',
#        'Quality of Life (VR-12 or Promis Global 10) Monitoring',
#        'Anesthesia: Patient Experience Survey'], dtype=object)

# %% [markdown]
# ## Physician Compare: Physician Utilization

# %%
# Importing and changing categories
pc_phys_util = pd.read_csv("physician_compare/Physician_Compare_Clinician_Utilization_Data.csv",
                  dtype = {"NPI" : "category",
                           "PAC ID" : "category",
                           "Last Name" : "object",
                           "First Name" : "object",
                           "Specialty" : "category",
                           "Practice State" : "category",
                           "HCPCS Code" : "category",
                           "Code Description" : "category",
                           "Service Count" : "int64",
                           "Beneficiary Count" : "int64"})
                              
# Display data frame
# pc_phys_util

# Determining what datatypes are available 
# pc_phys_util.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_phys_util['Code Description'].astype('str').unique()

# %%
pc_phys_util['Code Description'].astype('str').unique()
# Out:
# array(['Pathology examination of tissue using a microscope, moderately low complexity',
#        'Pathology examination of tissue using a microscope, intermediate complexity',
#        'Special stained specimen slides to examine tissue',
#        'Tissue or cell analysis by immunologic technique',
#        'Aspiration and/or injection of large joint or joint capsule',
#        'Injections of substances into lower or sacral spine',
#        'Injections of anesthetic and/or steroid drug into lower or sacral spine nerve root using imaging guidance',
#        'Cervical or vaginal cancer screening; pelvic and clinical breast examination',
#        'Screening papanicolaou smear; obtaining, preparing and conveyance of cervical or vaginal smear to laboratory',
#        'Removal of impact ear wax, one ear',
#        'Routine electrocardiogram (EKG) using at least 12 leads with interpretation and report',
#        'Physician certification for medicare-covered home health  services under a home health plan of care (patient not present), including contacts with home health agency and review of reports of patient status required by physicians to affirm the initial imple',
#        'Annual wellness visit, includes a personalized prevention plan of service (pps), subsequent visit',
#        'Urinalysis, manual test',
#        'Pneumococcal vaccine for injection into muscle',
#        'Routine EKG using at least 12 leads including interpretation and report',
#        'Administration of influenza virus vaccine',
#        'Administration of pneumococcal vaccine',
#        'Ultrasound measurement of bladder capacity after voiding',
#        'Diagnostic examination of the bladder and bladder canal (urethra) using an endoscope',
#        'X-ray of knee, 3 views', 'Physical therapy evaluation',
#        'Therapeutic exercise to develop strength, endurance, range of motion, and flexibility, each 15 minutes',
#        'Therapeutic procedure to re-educate brain-to-nerve-to-muscle function, each 15 minutes',
#        'Manual (physical) therapy techniques to 1 or more regions, each 15 minutes',
#        'Injection beneath the skin or into muscle for therapy, diagnosis, or prevention',
#        'Ultrasound of rectum',
#        'Insertion of needle into vein for collection of blood sample',
#        'Evaluation, testing, and programming adjustment of permanent dual lead pacemaker system with physician analysis, review, and report',
#        'Evaluation, testing and programming adjustment of defibrillator with analysis, review and report',
#        'Ultrasound examination of heart including color-depicted blood flow rate, direction, and valve function',
#        'Ultrasound scanning of blood flow (outside the brain) on both sides of head and neck',
#        'Biopsy of single growth of skin and/or tissue',
#        'Destruction of skin growth', 'Destruction of 2-14 skin growths',
#        'Destruction of up to 14 skin growths',
#        'Injection, triamcinolone  acetonide, not otherwise specified, 10 mg',
#        'Aspiration and/or injection of major joint or joint capsule with recording and reporting using ultrasound guidance',
#        'Ultrasonic guidance imaging supervision and interpretation for insertion of needle',
#        'Ultrasound study of arteries of both arms and legs',
#        'Drug screen, other than chromatographic; any number of drug classes, by clia waived test or moderate complexity test, per patient encounter',
#        'Injection, dexamethasone sodium phosphate, 1mg',
#        'Management of radiation therapy, complex',
#        'Management of radiation therapy, simulation, complex',
#        'Calculation of radiation therapy dose',
#        'Radiation treatment devices, design and construction, complex',
#        'Radiation treatment management, 5 treatments',
#        'X-ray of shoulder, minimum of 2 views',
#        'X-ray of ribs of one side of body, minimum of 2 views',
#        'X-ray of knee, 4 or more views',
#        'Psychiatric diagnostic evaluation',
#        'Psychotherapy, 60 minutes with patient and/or family member',
#        'Colorectal cancer screening; fecal occult blood test, immunoassay, 1-3 simultaneous',
#        'Chiropractic manipulative treatment, 3 to 4 spinal regions',
#        'X-ray of chest, 1 view, front',
#        'X-ray of chest, 2 views, front and side',
#        'CT scan of abdomen and pelvis',
#        'CT scan of abdomen and pelvis with contrast',
#        'Infusion of chemotherapy into a vein up to 1 hour',
#        'Automated urinalysis test', 'Ultrasound pelvis through vagina',
#        'Stool analysis for blood to screen for colon tumors',
#        'Injection, methylprednisolone acetate, 40 mg',
#        'Injections of tendon sheath, ligament, or muscle membrane',
#        'Injections of lower or sacral spine facet joint using imaging guidance',
#        'Drug screen, qualitative; multiple drug classes by high complexity test method (e.g., immunoassay, enzyme assay), per patient encounter',
#        'X-ray of abdomen, single view', 'Ultrasound of head and neck',
#        'Ultrasound scan of veins of both arms or legs including assessment of compression and functional maneuvers',
#        'Ultrasound scan of veins of one arm or leg or limited including assessment of compression and functional maneuvers',
#        'X-ray of wrist, minimum of 3 views',
#        'X-ray of hand, minimum of 3 views',
#        'X-ray of foot, minimum of 3 views',
#        'Ultrasound study of arteries and arterial grafts of both legs',
#        'Measurement and recording of brain wave (EEG) activity, awake and drowsy',
#        'Repair of knee joint',
#        'Application of ultrasound to 1 or more areas, each 15 minutes',
#        'Electrical stimulation (unattended), to one or more areas for indication(s) other than wound care, as part of a therapy plan of care',
#        'Measurement and recording of brain wave (EEG) activity, awake and asleep',
#        'Therapeutic activities to improve function, with one-on-one contact between patient and provider, each 15 minutes',
#        'Biopsy of each additional growth of skin and/or tissue',
#        'Hemodialysis procedure with one physician evaluation',
#        'Dialysis services (4 or more physician visits per month), patient 20 years of age and older',
#        'Dialysis services (2-3 physician visits per month), patient 20 years of age and older',
#        'Dialysis services (1 physician visit per month), patient 20 years of age and older',
#        'Hemoglobin A1C level', 'Eardrum testing using ear probe',
#        'Measurement and graphic recording of total and timed exhaled air capacity',
#        'Measurement and graphic recording of the amount and speed of breathed air, before and following medication administration',
#        'Determination of lung volumes using plethysmography',
#        'Measurement of lung diffusing capacity',
#        'Diagnostic examination of nasal passages using an endoscope',
#        'Diagnostic examination of voice box using flexible endoscope',
#        'Pathology examination of tissue using a microscope, moderately high complexity',
#        'Repair of wound (2.6 to 7.5 centimeters) of forehead, cheeks, chin, mouth, neck, underarms, genitals, hands, and/or feet',
#        'Tissue transfer repair of wound (10 sq centimeters or less) of eyelids, nose, ears, and/or lips',
#        'Injection of allergenic extracts into skin, accessed through the skin',
#        'Insertion of catheter in left heart for imaging of blood vessels or grafts and left lower heart',
#        'Physician re-certification for medicare-covered home health  services under a home health plan of care (patient not present), including contacts with home health agency and review of reports of patient status required by physicians to affirm the initial im',
#        'Anesthesia for procedure on gastrointestinal tract using an endoscope',
#        'Anesthesia for open or endoscopic total knee joint replacement',
#        'Nuclear medicine study of vessels of heart using drugs or exercise multiple studies',
#        'Exercise or drug-induced heart and blood vessel stress test with EKG monitoring, physician interpretation and report',
#        'Catheter insertion of stents in major coronary artery or branch, accessed through the skin',
#        'Anesthesia for lens surgery',
#        'Anesthesia for procedure in upper abdomen including use of an endoscope',
#        'Anesthesia for procedure on lower intestine using an endoscope',
#        'Insertion of arterial catheter for blood sampling or infusion, accessed through the skin',
#        'Moderate sedation services by physician also performing a procedure, patient 5 years of age or older, first 30 minutes',
#        'Blood glucose (sugar) test performed by hand-held instrument',
#        'Ultrasound guidance for accessing into blood vessel',
#        'Eye and medical examination for diagnosis and treatment, new patient, 1 or more visits',
#        'Eye and medical examination for diagnosis and treatment, established patient',
#        'Eye and medical examination for diagnosis and treatment, established patient, 1 or more visits',
#        'Measurement of field of vision during daylight conditions',
#        'Diagnostic imaging of optic nerve of eye',
#        'Diagnostic imaging of retina', 'Photography of the retina',
#        'Removal of skin and tissue first 20 sq cm or less',
#        'Removal of tissue from wounds per session',
#        'Needle measurement and recording of electrical activity of muscles of arm or leg complete study',
#        'Air and bone conduction assessment of hearing loss and speech recognition',
#        'Assessment of eardrum and muscle function',
#        'Chiropractic manipulative treatment, 1-2 spinal regions',
#        'Insertion of central venous catheter for infusion, patient 5 years or older',
#        'Removal of malignant growth (1.1 to 2.0 centimeters) of the face, ears, eyelids, nose, or lips',
#        'Chiropractic manipulative treatment, 5 spinal regions',
#        'Diagnostic examination of esophagus, stomach, and/or upper small bowel using an endoscope',
#        'Biopsy of the esophagus, stomach, and/or upper small bowel using an endoscope',
#        'Biopsy of large bowel using an endoscope',
#        'Removal of polyps or growths of large bowel using an endoscope',
#        'Diagnostic examination of large bowel using an endoscope',
#        'Nuclear medicine study of lung ventilation and blood circulation in the lungs',
#        'Emergent insertion of breathing tube into windpipe cartilage using an endoscope',
#        'Insertion of central venous catheter and implanted device for infusion beneath the skin, patient 5 years or older',
#        'Fluoroscopic guidance for insertion, replacement or removal of central venous access device',
#        'Radiological supervision and interpretation of CT guidance for needle insertion',
#        'Psychiatric diagnostic evaluation with medical services',
#        'Psychotherapy, 30 minutes with patient and/or family member',
#        'Fine needle aspiration using imaging guidance',
#        'Biopsy of prostate gland',
#        'Psychotherapy, 45 minutes with patient and/or family member',
#        'Removal of tissue from 1 to 5 finger or toe nails',
#        'Removal of tissue from 6 or more finger or toe nails',
#        'Removal of gallbladder using an endoscope',
#        'Nuclear medicine study with CT imaging skull base to mid-thigh',
#        'Bone and/or joint imaging, whole body',
#        'Removal of single thickened skin growth',
#        'Removal of 2 to 4 thickened skin growths',
#        'Complete blood cell count (red cells, white blood cell, platelets), automated test',
#        'X-ray of fingers, minimum of 2 views',
#        'Ultrasound study of arteries and arterial grafts of one leg or limited',
#        'Insertion of spinal instrumentation for spinal stabilization',
#        'Nuclear medicine study with CT imaging whole body',
#        'Fusion of spine bones with removal of disc at upper spinal column, anterior approach',
#        'Insertion of posterior spinal instrumentation for spinal stabilization, 3 to 6 vertebral segments',
#        'Partial removal of middle spine bone with release of spinal cord and/or nerves',
#        'Management and supervision of oxygen chamber therapy per session',
#        'Abdominal removal of uterus (250 grams or less) with removal of tubes and/or ovaries using an endoscope',
#        'Injection of incremental dosages of allergen, 2 or more injections',
#        'Partial removal of spine bone with release of spinal cord and/or nerves',
#        'Release and/or relocation of median nerve of hand',
#        'Sleep monitoring of patient (6 years or older) in sleep lab',
#        'Sleep monitoring of patient (6 years or older) in sleep lab with continued pressured respiratory assistance by mask or breathing tube',
#        'Occupational therapy evaluation',
#        'Infusion into a vein for therapy, prevention, or diagnosis up to 1 hour',
#        'Infusion into a vein for therapy prevention or diagnosis additional sequential infusion up to 1 hour',
#        'Nerve transmission studies, 5-6 studies',
#        'Biopsy or removal of lymph nodes of under the arm, open procedure',
#        'Lymph node imaging during surgery',
#        'Treatment of speech, language, voice, communication, and/or hearing processing disorder',
#        'Preparation and provision of single or multiple antigens for allergen immunotherapy',
#        'Injection of allergenic extracts into skin for immediate reaction analysis',
#        'Medical nutrition therapy, assessment and intervention, each 15 minutes',
#        'Medical nutrition therapy re-assessment and intervention, each 15 minutes',
#        'Medical nutrition therapy; reassessment and subsequent intervention(s) following second referral in same year for change in diagnosis, medical condition or treatment regimen (including additional hours needed for renal disease), individual, face to face wi',
#        'Observation, testing, and recording of abnormal eye movement',
#        'Nerve transmission studies, 7-8 studies',
#        'Harvest of veins for coronary artery bypass procedure using an endoscope',
#        'Heart artery bypass to repair one artery',
#        'Insertion of new or replacement of permanent pacemaker including upper and lower chamber electrodes',
#        'Removal of hemorrhoid by rubber banding',
#        'Home dialysis services per month, patient 20 years of age or older',
#        'Diabetes outpatient self-management training services, individual, per 30 minutes',
#        'Assessment and recording of balance system during irrigation of both ears',
#        'Osteopathic manipulative treatment to 3-4 body regions',
#        'Osteopathic manipulative treatment to 5-6 body regions',
#        'Osteopathic manipulative treatment to 7-8 body regions',
#        'Osteopathic manipulative treatment to 9-10 body regions',
#        'Neuropsychological testing, interpretation, and report by psychologist or physician per hour',
#        'Diagnostic examination of the anus using an endoscope',
#        'X-ray imaging of teeth',
#        'Combined multiple vein and artery heart artery bypasses',
#        'Group psychotherapy',
#        'Diabetes outpatient self-management training services, group session (2 or more), per 30 minutes',
#        'Replacement of left lower heart chamber valve using artificial valve on heart-lung machine',
#        'Shock treatment and monitoring',
#        'X-ray of mandible, less than 4 views',
#        'Unattended sleep study with recording of heart rate, oxygen, respiratory airflow and effort',
#        'Partial removal of breast',
#        'Impression and custom preparation of outer ear prosthesis',
#        'Evaluation of swallowing function', 'Removal of growth of mouth',
#        'Evaluation of speech sound production with evaluation of language comprehension and expression',
#        'Behavioral and qualitative analysis of voice and resonance',
#        'Treatment of swallowing and/or oral feeding function',
#        'Complex motion imaging procedure on both sides of body',
#        'Biopsy of mouth',
#        'Imaging of jaws and skull for orthodontic purposes',
#        'Repair of nasal or cheek bone with bone graft',
#        'X-ray of jaw joints on both sides of the face'], dtype=object)

# %% [markdown]
# ## Physician Compare: Physician Details

# %%
# Importing and changing categories
pc_phys_details = pd.read_csv("physician_compare/Physician_Compare_National_Downloadable_File.csv",
                  dtype = {"NPI" : "category",
                           "PAC ID" : "category",
                           "Professional Enrollment ID" : "category",
                           "Last Name" : "object",
                           "First Name" : "object",
                           "Middle Name" : "object",
                           "Suffix" : "object",
                           "Gender" : "category",
                           "Measure Identifier" : "category",
                           "Credential" : "category",
                           "Medical school name" : "category",
                           "Primary Specialty" : "category",
                           "Secondary Specialty 1" : "category",
                           "Secondary Specialty 2" : "category",
                           "Secondary Specialty 3" : "category",
                           "Secondary Specialty 4" : "category",
                           "All secondary specialties" : "object",
                           "Organization legal name" : "object",
                           "Group Practice PAC ID" : "object",
                           "Line 1 Street Address" : "object",
                           "Line 2 Street Address" : "object",
                           "Marker of address line 2 suppression" : "object",
                           "City" : "category",
                           "State" : "category",
                           "Zip Code" : "category",
                           "Phone Number" : "object",
                           "Hospital affiliation CCN 1" : "category",
                           "Hospital affiliation LBN 1" : "category",
                           "Hospital affiliation CCN 2" : "category",
                           "Hospital affiliation LBN 2" : "category",
                           "Hospital affiliation CCN 3" : "category",
                           "Hospital affiliation LBN 3" : "category",
                           "Hospital affiliation CCN 4" : "category",
                           "Hospital affiliation LBN 4" : "category",
                           "Hospital affiliation CCN 5" : "category",
                           "Hospital affiliation LBN 5" : "category",
                           "Professional accepts Medicare Assignment" : "category",
                           "Graduation year" : "object",
                           "Number of Group Practice members" : "object"},
                           converters={"Reported Quality Measures": lambda x:convert_bool(x),
                                      "Used electronic health records": lambda x:convert_bool(x),
                                      "Committed to heart health through the Million Hearts® initiative.": lambda x:convert_bool(x)})

# Converting to boolean
pc_phys_details["Reported Quality Measures"] = pc_phys_details["Reported Quality Measures"].astype("bool")
pc_phys_details["Used electronic health records"] = pc_phys_details["Used electronic health records"].astype("bool")
pc_phys_details["Committed to heart health through the Million Hearts® initiative."] = pc_phys_details["Committed to heart health through the Million Hearts® initiative."].astype("bool")


# Handling NA values for integer data types 
pc_phys_details['Graduation year'] = pc_phys_details['Graduation year'].replace(np.nan, 0)
pc_phys_details['Number of Group Practice members'] = pc_phys_details['Number of Group Practice members'].replace(np.nan, 0)

pc_phys_details['Graduation year'] = pc_phys_details['Graduation year'].astype(int)
pc_phys_details['Number of Group Practice members'] = pc_phys_details['Number of Group Practice members'].astype(int)


# Display data frame
#pc_phys_details

# Determining what datatypes are available 
pc_phys_details.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_phys_details['...'].astype('str').unique()
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# NPI                                                                  category
# PAC ID                                                               category
# Professional Enrollment ID                                           category
# Last Name                                                              object
# First Name                                                             object
# Middle Name                                                            object
# Suffix                                                                 object
# Gender                                                               category
# Credential                                                           category
# Medical school name                                                  category
# Graduation year                                                         int64
# Primary specialty                                                      object
# Secondary specialty 1                                                  object
# Secondary specialty 2                                                  object
# Secondary specialty 3                                                  object
# Secondary specialty 4                                                  object
# All secondary specialties                                              object
# Organization legal name                                                object
# Group Practice PAC ID                                                  object
# Number of Group Practice members                                        int64
# Line 1 Street Address                                                  object
# Line 2 Street Address                                                  object
# Marker of address line 2 suppression                                   object
# City                                                                 category
# State                                                                category
# Zip Code                                                             category
# Phone Number                                                           object
# Hospital affiliation CCN 1                                           category
# Hospital affiliation LBN 1                                           category
# Hospital affiliation CCN 2                                           category
# Hospital affiliation LBN 2                                           category
# Hospital affiliation CCN 3                                           category
# Hospital affiliation LBN 3                                           category
# Hospital affiliation CCN 4                                           category
# Hospital affiliation LBN 4                                           category
# Hospital affiliation CCN 5                                           category
# Hospital affiliation LBN 5                                           category
# Professional accepts Medicare Assignment                             category
# Reported Quality Measures                                                bool
# Used electronic health records                                           bool
# Committed to heart health through the Million Hearts® initiative.        bool
# dtype: object

# %% [markdown]
# ## NPI Dataset

# %%
npi = pd.read_csv("npi/pl_pfile_20050523-20180909.csv",
                  dtype ={"NPI" : "category",
                          "Provider Secondary Practice Location Address- Address Line 1": "object",
                          "Provider Secondary Practice Location Address-  Address Line 2": "object",
                          "Provider Secondary Practice Location Address - City Name": "category", 
                          "Provider Secondary Practice Location Address - State Name": "category", 
                          "Provider Secondary Practice Location Address - Postal Code": "category", 
                          "Provider Secondary Practice Location Address - Country Code (If outside U.S.)": "category", 
                          "Provider Secondary Practice Location Address - Telephone Number": "object", 
                          "Provider Secondary Practice Location Address - Telephone Extension": "object", 
                          "Provider Practice Location Address - Fax Number": "object"})

# Display data frame
# npi

# Determining what datatypes are available 
npi.dtypes
# Out:
# NPI                                                                              category
# Provider Secondary Practice Location Address- Address Line 1                       object
# Provider Secondary Practice Location Address-  Address Line 2                      object
# Provider Secondary Practice Location Address - City Name                         category
# Provider Secondary Practice Location Address - State Name                        category
# Provider Secondary Practice Location Address - Postal Code                       category
# Provider Secondary Practice Location Address - Country Code (If outside U.S.)    category
# Provider Secondary Practice Location Address - Telephone Number                    object
# Provider Secondary Practice Location Address - Telephone Extension                 object
# Provider Practice Location Address - Fax Number                                    object
# dtype: object

# %% [markdown]
# ## Census Data
