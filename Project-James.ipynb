# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating function to change Y/N to boolean

# %%
def convert_bool(col):
    if str(col).title() ==  "Y": #check for nan
        return True
    elif str(col).title() == "N":
        return False
    else:
        return col

# %% [markdown]
# ### Importing data set from Physician Compare - Organization Performance

# %%
# Importing and changing categories
pc_org_perf = pd.read_csv("physician_compare/Physician_Compare_2016_Group_Public_Reporting.csv",
                  dtype = {"Organization legal name or 'doing business as' name" : "category",
                           "Group PAC ID" : "category",
                           "State" : "category",
                           "ACO PC ID 1" : "category",
                           "ACO Name 1" : "category",
                           "ACO PC ID 2" : "category",
                           "ACO Name 2" : "category",
                           "Measure Identifier" : "category",
                           "Measure Title" : "category",
                           "Measure Performance Rate": "float64",
                           "Denominator Count": "float64",
                           "Star Value": "float64",
                           "Five Star Benchmark": "float64",
                           "Footnote": "object",
                           "Collection Type": "object"},
                 converters={"Participating in PQRS": lambda x:convert_bool(x),
                             "Inverse Measure": lambda x:convert_bool(x),
                             "Reported on PC Live Site": lambda x:convert_bool(x)})

# Changing to boolean
pc_org_perf["Participating in PQRS"] = pc_org_perf["Participating in PQRS"].astype("bool")
pc_org_perf["Inverse Measure"] = pc_org_perf["Inverse Measure"].astype("bool")
pc_org_perf["Reported on PC Live Site"] = pc_org_perf["Reported on PC Live Site"].astype("bool")

# Display data frame
# pc_org_report

##Determining what datatypes are available 
#pc_org_perf.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_org_perf['Measure Title'].astype('str').unique()

# %% [markdown]
# ### Importing data set from Physician Compare - Patient's Organization Experience

# %%
# Importing and changing categories
pc_org_pt_exp = pd.read_csv("physician_compare/Physician_Compare_2016_Group_Public_Reporting-_Patient_Experience.csv",
                  dtype = {"Organization legal name or 'doing business as' name" : "category",
                           "Group PAC ID" : "category",
                           "State" : "category",
                           "Measure Identifier" : "category",
                           "Measure Title" : "category",
                           "Measure Performance Rate": "float64",
                           "Denominator Count": "float64",
                           "Footnote": "object"})

# Display data frame
# pc_org_pt_exp

##Determining what datatypes are available 
#pc_org_report.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_org_pt_exp['Measure Title'].astype('str').unique()

# %% [markdown]
# ### Importing data set from Physician Compare - Physician Performance

# %%
# Importing and changing categories
pc_phys_perf = pd.read_csv("physician_compare/Physician_Compare_2016_Individual_EP_Public_Reporting.csv",
                  dtype = {"NPI" : "category",
                           "PAC ID" : "category",
                           "Last Name" : "object",
                           "First Name" : "object",
                           "Measure Identifier" : "category",
                           "Measure Title" : "category",
                           "Measure Performance Rate": "float64",
                           "Reporting Mechanism": "category",
                           "Footnote": "object"},
                           converters={"Inverse Measure": lambda x:convert_bool(x),
                                      "Reported on PC Live Site": lambda x:convert_bool(x)})

# Converting to boolean
pc_phys_perf["Inverse Measure"] = pc_phys_perf["Inverse Measure"].astype("bool")
pc_phys_perf["Reported on PC Live Site"] = pc_phys_perf["Reported on PC Live Site"].astype("bool")

# Display data frame
pc_phys_perf

##Determining what datatypes are available 
#pc_phys_perf.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_phys_perf['Measure Title'].astype('str').unique()
# Out:
#                NPI      PAC ID    Last Name First Name Measure Identifier  \
# 0       1508823618  0042100117      GRIFFIN      DAVID      PQRS_EP_110_1
# 1       1508823618  0042100117      GRIFFIN      DAVID      PQRS_EP_111_1
# 2       1508823618  0042100117      GRIFFIN      DAVID      PQRS_EP_113_1
# 3       1508823618  0042100117      GRIFFIN      DAVID      PQRS_EP_130_1
# 4       1508823618  0042100117      GRIFFIN      DAVID      PQRS_EP_226_1
# 5       1508823618  0042100117      GRIFFIN      DAVID       PQRS_EP_39_1
# 6       1508823618  0042100117      GRIFFIN      DAVID       PQRS_EP_48_1
# 7       1154338044  0042100190    VERBRUGGE       JOHN       PQRS_EP_47_1
# 8       1285691733  0042100323     LAPLANTE    DRUANNE      PQRS_EP_110_1
# 9       1285691733  0042100323     LAPLANTE    DRUANNE      PQRS_EP_111_1
# 10      1285691733  0042100323     LAPLANTE    DRUANNE      PQRS_EP_130_1
# 11      1285691733  0042100323     LAPLANTE    DRUANNE      PQRS_EP_226_1
# 12      1285691733  0042100323     LAPLANTE    DRUANNE       PQRS_EP_47_1
# 13      1922007376  0042100968      PREBISH    RICHARD      PQRS_EP_131_1
# 14      1922007376  0042100968      PREBISH    RICHARD      PQRS_EP_182_1
# 15      1881799146  0042101156         NATH      MANOJ      PQRS_EP_130_1
# 16      1881799146  0042101156         NATH      MANOJ       PQRS_EP_47_1
# 17      1417040411  0042101214       TANTRA      ZUBIN      PQRS_EP_130_1
# 18      1417040411  0042101214       TANTRA      ZUBIN      PQRS_EP_131_1
# 19      1417040411  0042101214       TANTRA      ZUBIN      PQRS_EP_182_1
# 20      1396828901  0042101651        CYRAN    FRANCIS       PQRS_EP_23_1
# 21      1225135908  0042101685      MADANAY       LYNN      PQRS_EP_147_1
# 22      1619966041  0042101917      ROBBINS    FRANCIS      PQRS_EP_130_1
# 23      1619966041  0042101917      ROBBINS    FRANCIS      PQRS_EP_226_1
# 24      1134110596  0042102055          GAO     ROBERT      PQRS_EP_130_1
# 25      1134110596  0042102055          GAO     ROBERT       PQRS_EP_47_1
# 26      1609874395  0042102220        KEZIS    JEFFREY      PQRS_EP_137_1
# 27      1609874395  0042102220        KEZIS    JEFFREY      PQRS_EP_224_1
# 28      1609874395  0042102220        KEZIS    JEFFREY      PQRS_EP_238_1
# 29      1609874395  0042102220        KEZIS    JEFFREY      PQRS_EP_265_1
# ...            ...         ...          ...        ...                ...
# 325233  1891131124  9931495223       MEDINA     PAMELA      PQRS_EP_130_1
# 325234  1891131124  9931495223       MEDINA     PAMELA       PQRS_EP_47_1
# 325235  1114324613  9931495389   WEDDERBURN       IONA      PQRS_EP_130_1
# 325236  1114324613  9931495389   WEDDERBURN       IONA       PQRS_EP_47_1
# 325237  1720532831  9931495587      PROCTOR    BRIANNA      PQRS_EP_130_1
# 325238  1720532831  9931495587      PROCTOR    BRIANNA      PQRS_EP_131_1
# 325239  1720532831  9931495587      PROCTOR    BRIANNA      PQRS_EP_182_1
# 325240  1184024374  9931495603     VARGHESE      ROGER      PQRS_EP_113_1
# 325241  1184024374  9931495603     VARGHESE      ROGER      PQRS_EP_130_1
# 325242  1184024374  9931495603     VARGHESE      ROGER      PQRS_EP_226_1
# 325243  1679880371  9931495736        ATAYA       DANA      PQRS_EP_225_1
# 325244  1801190988  9931497617  CHRISTENSEN      CAROL      PQRS_EP_110_1
# 325245  1801190988  9931497617  CHRISTENSEN      CAROL      PQRS_EP_111_1
# 325246  1801190988  9931497617  CHRISTENSEN      CAROL      PQRS_EP_113_1
# 325247  1801190988  9931497617  CHRISTENSEN      CAROL      PQRS_EP_130_1
# 325248  1801190988  9931497617  CHRISTENSEN      CAROL      PQRS_EP_226_1
# 325249  1801190988  9931497617  CHRISTENSEN      CAROL       PQRS_EP_39_1
# 325250  1801190988  9931497617  CHRISTENSEN      CAROL       PQRS_EP_47_1
# 325251  1558713834  9931497757     CIPRIANO      BELLA      PQRS_EP_130_1
# 325252  1558713834  9931497757     CIPRIANO      BELLA      PQRS_EP_131_1
# 325253  1558713834  9931497757     CIPRIANO      BELLA      PQRS_EP_182_1
# 325254  1780003624  9931498060       DAVILA    WILLIAM      PQRS_EP_110_1
# 325255  1780003624  9931498060       DAVILA    WILLIAM      PQRS_EP_111_1
# 325256  1780003624  9931498060       DAVILA    WILLIAM      PQRS_EP_113_1
# 325257  1780003624  9931498060       DAVILA    WILLIAM      PQRS_EP_130_1
# 325258  1780003624  9931498060       DAVILA    WILLIAM      PQRS_EP_226_1
# 325259  1780003624  9931498060       DAVILA    WILLIAM       PQRS_EP_47_1
# 325260  1780003624  9931498060       DAVILA    WILLIAM       PQRS_EP_48_1
# 325261  1265880660  9931499613   VANDERLAAN     ALISSA      PQRS_EP_130_1
# 325262  1265880660  9931499613   VANDERLAAN     ALISSA      PQRS_EP_226_1
#
#                                             Measure Title  Inverse Measure  \
# 0       Preventive Care and Screening: Influenza Immun...            False
# 1           Pneumonia Vaccination Status for Older Adults            False
# 2                             Colorectal Cancer Screening            False
# 3       Documentation of Current Medications in the Me...            False
# 4       Preventive Care and Screening: Tobacco Use: Sc...            False
# 5       Screening or Therapy for Osteoporosis for Wome...            False
# 6       Urinary Incontinence: Assessment of Presence o...            False
# 7                                       Advance Care Plan            False
# 8       Preventive Care and Screening: Influenza Immun...            False
# 9           Pneumonia Vaccination Status for Older Adults            False
# 10      Documentation of Current Medications in the Me...            False
# 11      Preventive Care and Screening: Tobacco Use: Sc...            False
# 12                                      Advance Care Plan            False
# 13                          Pain Assessment and Follow-Up            False
# 14                          Functional Outcome Assessment            False
# 15      Documentation of Current Medications in the Me...            False
# 16                                      Advance Care Plan            False
# 17      Documentation of Current Medications in the Me...            False
# 18                          Pain Assessment and Follow-Up            False
# 19                          Functional Outcome Assessment            False
# 20      Perioperative Care: Venous Thromboembolism (VT...            False
# 21      Nuclear Medicine: Correlation with Existing Im...            False
# 22      Documentation of Current Medications in the Me...            False
# 23      Preventive Care and Screening: Tobacco Use: Sc...            False
# 24      Documentation of Current Medications in the Me...            False
# 25                                      Advance Care Plan            False
# 26           Melanoma: Continuity of Care - Recall System            False
# 27      Melanoma: Overutilization of Imaging Studies i...            False
# 28            Use of High-Risk Medications in the Elderly             True
# 29                                       Biopsy Follow-Up            False
# ...                                                   ...              ...
# 325233  Documentation of Current Medications in the Me...            False
# 325234                                  Advance Care Plan            False
# 325235  Documentation of Current Medications in the Me...            False
# 325236                                  Advance Care Plan            False
# 325237  Documentation of Current Medications in the Me...            False
# 325238                      Pain Assessment and Follow-Up            False
# 325239                      Functional Outcome Assessment            False
# 325240                        Colorectal Cancer Screening            False
# 325241  Documentation of Current Medications in the Me...            False
# 325242  Preventive Care and Screening: Tobacco Use: Sc...            False
# 325243  Radiology: Reminder System for Screening Mammo...            False
# 325244  Preventive Care and Screening: Influenza Immun...            False
# 325245      Pneumonia Vaccination Status for Older Adults            False
# 325246                        Colorectal Cancer Screening            False
# 325247  Documentation of Current Medications in the Me...            False
# 325248  Preventive Care and Screening: Tobacco Use: Sc...            False
# 325249  Screening or Therapy for Osteoporosis for Wome...            False
# 325250                                  Advance Care Plan            False
# 325251  Documentation of Current Medications in the Me...            False
# 325252                      Pain Assessment and Follow-Up            False
# 325253                      Functional Outcome Assessment            False
# 325254  Preventive Care and Screening: Influenza Immun...            False
# 325255      Pneumonia Vaccination Status for Older Adults            False
# 325256                        Colorectal Cancer Screening            False
# 325257  Documentation of Current Medications in the Me...            False
# 325258  Preventive Care and Screening: Tobacco Use: Sc...            False
# 325259                                  Advance Care Plan            False
# 325260  Urinary Incontinence: Assessment of Presence o...            False
# 325261  Documentation of Current Medications in the Me...            False
# 325262  Preventive Care and Screening: Tobacco Use: Sc...            False
#
#         Measure Performance Rate  Denominator Count Collection Type  \
# 0                           20.0                 71             CLM
# 1                           41.0                 90             CLM
# 2                           29.0                 70             CLM
# 3                           91.0                255             CLM
# 4                           98.0                104             CLM
# 5                           46.0                 87             CLM
# 6                            6.0                 90             CLM
# 7                           85.0                105             CLM
# 8                           52.0                 71             CLM
# 9                           77.0                 60             CLM
# 10                          95.0                212             CLM
# 11                          94.0                 68             CLM
# 12                           5.0                 60             CLM
# 13                         100.0                658             CLM
# 14                         100.0                652             CLM
# 15                         100.0                 25             CLM
# 16                          72.0                122             CLM
# 17                          91.0                 34             CLM
# 18                         100.0                 41             CLM
# 19                          98.0                 42             CLM
# 20                         100.0                 86             CLM
# 21                         100.0                 59             CLM
# 22                         100.0                848             CLM
# 23                         100.0                678             CLM
# 24                          99.0                591             CLM
# 25                          85.0                512             CLM
# 26                         100.0                 38             REG
# 27                         100.0                 38             REG
# 28                           0.0                832             REG
# 29                         100.0                 41             REG
# ...                          ...                ...             ...
# 325233                      83.0                 24             CLM
# 325234                      93.0                 59             CLM
# 325235                     100.0                 20             CLM
# 325236                     100.0                 27             CLM
# 325237                     100.0                 27             CLM
# 325238                     100.0                 28             CLM
# 325239                     100.0                 27             CLM
# 325240                      94.0                 31             CLM
# 325241                      97.0                 69             CLM
# 325242                      94.0                 54             CLM
# 325243                     100.0                 28             CLM
# 325244                       2.0                 48             CLM
# 325245                      41.0                 44             CLM
# 325246                      49.0                 43             CLM
# 325247                     100.0                 81             CLM
# 325248                     100.0                 66             CLM
# 325249                      46.0                 24             CLM
# 325250                      14.0                 44             CLM
# 325251                     100.0                 30             CLM
# 325252                      96.0                 27             CLM
# 325253                      97.0                 29             CLM
# 325254                      37.0                 87             CLM
# 325255                     100.0                 68             CLM
# 325256                     100.0                 81             CLM
# 325257                      96.0                135             CLM
# 325258                     100.0                116             CLM
# 325259                     100.0                 68             CLM
# 325260                     100.0                 36             CLM
# 325261                     100.0                 50             CLM
# 325262                     100.0                 22             CLM
#
#         Reported on PC Live Site
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# 5                          False
# 6                          False
# 7                          False
# 8                          False
# 9                          False
# 10                         False
# 11                         False
# 12                         False
# 13                         False
# 14                         False
# 15                         False
# 16                         False
# 17                         False
# 18                         False
# 19                         False
# 20                         False
# 21                         False
# 22                         False
# 23                         False
# 24                         False
# 25                         False
# 26                         False
# 27                         False
# 28                         False
# 29                         False
# ...                          ...
# 325233                     False
# 325234                     False
# 325235                     False
# 325236                     False
# 325237                     False
# 325238                     False
# 325239                     False
# 325240                     False
# 325241                     False
# 325242                     False
# 325243                     False
# 325244                     False
# 325245                     False
# 325246                     False
# 325247                     False
# 325248                     False
# 325249                     False
# 325250                     False
# 325251                     False
# 325252                     False
# 325253                     False
# 325254                     False
# 325255                     False
# 325256                     False
# 325257                     False
# 325258                     False
# 325259                     False
# 325260                     False
# 325261                     False
# 325262                     False
#
# [325263 rows x 11 columns]

# %% [markdown]
# ### Importing data set from Physician Compare - Physician Utilization
#
# Probably will not use this data set.

# %%
# Importing and changing categories
pc_phys_util = pd.read_csv("physician_compare/Physician_Compare_Clinician_Utilization_Data.csv",
                  dtype = {"NPI" : "category",
                           "PAC ID" : "category",
                           "Last Name" : "object",
                           "First Name" : "object",
                           "Specialty" : "category",
                           "Practice State" : "category",
                           "HCPCS Code" : "category",
                           "Code Description" : "category",
                           "Service Count" : "int64",
                           "Beneficiary Count" : "int64"})
                              
# Display data frame
# pc_phys_util

# Determining what datatypes are available 
# pc_phys_util.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_phys_util['Code Description'].astype('str').unique()

# %% [markdown]
# ### Importing data set from Physician Compare - Physician Details

# %%
# Importing and changing categories
pc_phys_details = pd.read_csv("physician_compare/Physician_Compare_National_Downloadable_File.csv",
                  dtype = {"NPI" : "category",
                           "PAC ID" : "category",
                           "Professional Enrollment ID" : "category",
                           "Last Name" : "object",
                           "First Name" : "object",
                           "Middle Name" : "object",
                           "Suffix" : "object",
                           "Gender" : "category",
                           "Measure Identifier" : "category",
                           "Credential" : "category",
                           "Medical school name" : "category",
                           "Primary Specialty" : "category",
                           "Secondary Specialty 1" : "category",
                           "Secondary Specialty 2" : "category",
                           "Secondary Specialty 3" : "category",
                           "Secondary Specialty 4" : "category",
                           "All secondary specialties" : "object",
                           "Organization legal name" : "object",
                           "Group Practice PAC ID" : "object",
                           "Line 1 Street Address" : "object",
                           "Line 2 Street Address" : "object",
                           "Marker of address line 2 suppression" : "object",
                           "City" : "category",
                           "State" : "category",
                           "Zip Code" : "category",
                           "Phone Number" : "object",
                           "Hospital affiliation CCN 1" : "category",
                           "Hospital affiliation LBN 1" : "category",
                           "Hospital affiliation CCN 2" : "category",
                           "Hospital affiliation LBN 2" : "category",
                           "Hospital affiliation CCN 3" : "category",
                           "Hospital affiliation LBN 3" : "category",
                           "Hospital affiliation CCN 4" : "category",
                           "Hospital affiliation LBN 4" : "category",
                           "Hospital affiliation CCN 5" : "category",
                           "Hospital affiliation LBN 5" : "category",
                           "Professional accepts Medicare Assignment" : "category",
                           "Graduation year" : "object",
                           "Number of Group Practice members" : "object"},
                           converters={"Reported Quality Measures": lambda x:convert_bool(x),
                                      "Used electronic health records": lambda x:convert_bool(x),
                                      "Committed to heart health through the Million Hearts® initiative.": lambda x:convert_bool(x)})

# Converting to boolean
pc_phys_details["Reported Quality Measures"] = pc_phys_details["Reported Quality Measures"].astype("bool")
pc_phys_details["Used electronic health records"] = pc_phys_details["Used electronic health records"].astype("bool")
pc_phys_details["Committed to heart health through the Million Hearts® initiative."] = pc_phys_details["Committed to heart health through the Million Hearts® initiative."].astype("bool")


# Handling NA values for integer data types 
pc_phys_details['Graduation year'] = pc_phys_details['Graduation year'].replace(np.nan, 0).astype(int)
pc_phys_details['Number of Group Practice members'] = pc_phys_details['Number of Group Practice members'].replace(np.nan, 0).astype(int)

# pc_phys_details['Graduation year'] = pc_phys_details['Graduation year']
# pc_phys_details['Number of Group Practice members'] = pc_phys_details['Number of Group Practice members']


# Display data frame
#pc_phys_details

# Determining what datatypes are available 
pc_phys_details.dtypes

# Find what unique categories are avilable. Converted to string for easier reading.
# pc_phys_details['...'].astype('str').unique()

# %% [markdown]
# ### Importing NPI Data

# %%
npi = pd.read_csv("npi/pl_pfile_20050523-20180909.csv",
                  dtype ={"NPI" : "category",
                          "Provider Secondary Practice Location Address- Address Line 1": "object",
                          "Provider Secondary Practice Location Address-  Address Line 2": "object",
                          "Provider Secondary Practice Location Address - City Name": "category", 
                          "Provider Secondary Practice Location Address - State Name": "category", 
                          "Provider Secondary Practice Location Address - Postal Code": "object", 
                          "Provider Secondary Practice Location Address - Country Code (If outside U.S.)": "category", 
                          "Provider Secondary Practice Location Address - Telephone Number": "object", 
                          "Provider Secondary Practice Location Address - Telephone Extension": "object", 
                          "Provider Practice Location Address - Fax Number": "object"})

# Zipcode correction 
npi['zipcode'] = npi["Provider Secondary Practice Location Address - Postal Code"].astype(str).str[:5]

# Display data frame
npi

# Determining what datatypes are available 
# npi.dtypes

# %%
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (17,24,26,27,32,34,35,39,40,46,60,61,64,65,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98,99,100,101,102,103,104,105,106,111,115,117,118,119,121,122,123,125,126,127,129,130,131,133,134,135,137,138,139,141,142,143,145,146,147,149,150,151,153,154,155,157,158,159,161,162,163,165,166,167,169,170,171,173,174,175,177,178,179,181,182,183,185,186,187,189,190,191,193,194,195,197,198,199,201,202,203,205,206,207,209,210,211,213,214,215,217,218,219,221,222,223,225,226,227,229,230,231,233,234,235,237,238,239,241,242,243,245,246,247,249,250,251,253,254,255,257,258,259,261,262,263,265,266,267,269,270,271,273,274,275,277,278,279,281,282,283,285,286,287,289,290,291,293,294,295,297,298,299,301,302,303,305,306,312,316,317,318,319,320,321,322,323,324,325,326,327,328) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-a7d8edb924fd> in <module>()
# ----> 1 df6 = pd.read_csv("npi/npidata_pfile_20050523-20180909.csv")
#       2 df6
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1049             new_rows = len(index)
#    1050
# -> 1051         df = DataFrame(col_dict, columns=columns, index=index)
#    1052
#    1053         self._currow += new_rows
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7362     axes = [_ensure_index(columns), _ensure_index(index)]
#    7363
# -> 7364     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    7365
#    7366
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4870
#    4871     try:
# -> 4872         blocks = form_blocks(arrays, names, axes)
#    4873         mgr = BlockManager(blocks, axes)
#    4874         mgr._consolidate_inplace()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in form_blocks(arrays, names, axes)
#    4936
#    4937     if len(items_dict['ObjectBlock']) > 0:
# -> 4938         object_blocks = _simple_blockify(items_dict['ObjectBlock'], np.object_)
#    4939         blocks.extend(object_blocks)
#    4940
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _simple_blockify(tuples, dtype)
#    4974     not None, coerce to this dtype
#    4975     """
# -> 4976     values, placement = _stack_arrays(tuples, dtype)
#    4977
#    4978     # CHECK DTYPE?
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in _stack_arrays(tuples, dtype)
#    5035     shape = (len(arrays),) + _shape_compat(first)
#    5036
# -> 5037     stacked = np.empty(shape, dtype=dtype)
#    5038     for i, arr in enumerate(arrays):
#    5039         stacked[i] = _asarray_compat(arr)
#
# MemoryError:
